# %%
i = 5
print(i)

# %%
for i in range(0,5):
    print(i)

# %% [markdown]
# ## This is markdown
#
# Like this.

# %%
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    fruits.remove(fruit)
print(fruits)

# %%
# another cell not run
print("Hello, World!")
