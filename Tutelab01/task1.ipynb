# %%
i = 5
print(i)
# Out:
# 5

# %%
# copilot generated
def load_csv_to_df(path):
    import pandas as pd
    return pd.read_csv(path)

df = load_csv_to_df('data.csv')
print(df.head())
# Out:
#    num1   num2  code
# 0    12   87.0  ABCD
# 1    45    3.0  WXYZ
# 2    78  -56.0  LMNO
# 3     9  100.0  QRST
# 4    33   21.0  UVWX

# %%
# clean data file, ensure no missing values, 
# no negative values.

# Grok-generated and then edited

df_clean = df.dropna()
df_clean = df_clean[(df_clean['num1'] >= 0) & (df_clean['num2'] >= 0)]  # Keep only rows where num1 and num2 are non-negative
print(df_clean.describe())  # Optional: print the cleaned dataframe head
# Out:
#             num1        num2
# count   8.000000    8.000000
# mean   41.375000   45.750000
# std    27.176342   39.365503
# min     9.000000    3.000000
# 25%    23.250000    9.500000
# 50%    39.000000   43.000000
# 75%    54.250000   75.750000
# max    90.000000  100.000000

# %%
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## This is markdown
#
# Like this.

# %%
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    fruits.remove(fruit)
print(fruits)
# Out:
# ['banana']

# %%
# another cell not run
print("Hello, World!")
# Out:
# Hello, World!
